# %% [markdown]
# # CO416 - Machine Learning for  Imaging

# %% [markdown]
# ## Coursework 2 - Age regression from brain MRI

# %% [markdown]
# Predicting age from a brain MRI scan can have diagnostic value for a number of diseases that cause structural changes and damage to the brain. Discrepancy between the predicted, biological age and the real, chronological age of a patient might indicate the presence of disease and abnormal changes to the brain. For this we need an accurate predictor of brain age which may be learned from a set of healthy reference subjects.
# The objective for the coursework is to implement two different supervised learning approaches for age regression from brain MRI. Data from 600 healthy subjects will be provided. Each approach will require a processing pipeline with different components that you will need to implement using methods that were discussed in the lectures and tutorials. There are dedicated sections in the Jupyter notebook for each approach which contain some detailed instructions, hints and notes.
#
# You may find useful ideas and implementations in the tutorial notebooks. Make sure to add documentation to your code. Markers will find it easier to understand your reasoning when sufficiently detailed comments are provided in your implementations.
#
# #### Read the descriptions and provided code cells carefully and look out for the cells marked with 'TASK'.

# %% [markdown]
# ### Getting started and familiarise ourselves with the data
#
# The following cells provide some helper functions to load the data, and provide some overview and visualisation of the statistics over the population of 600 subjects. Let's start by loading the meta data, that is the data containing information about the subject IDs, their age, and gender.

# %%
# Read the meta data using pandas
import pandas as pd

data_dir = "./data/brain/"

meta_data = pd.read_csv(data_dir + 'meta/clean_participant_data.csv')
meta_data.head() # show the first five data entries
# Out:
#          ID  age  gender_code gender_text
# 0  CC110033   24            1        MALE
# 1  CC110037   18            1        MALE
# 2  CC110045   24            2      FEMALE
# 3  CC110056   22            2      FEMALE
# 4  CC110062   20            1        MALE

# %% [markdown]
# Let's have a look at some population statistics.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

sns.catplot(x="gender_text", data=meta_data, kind="count")
plt.title('Gender distribution')
plt.xlabel('Gender')
plt.show()

sns.distplot(meta_data['age'], bins=[10,20,30,40,50,60,70,80,90])
plt.title('Age distribution')
plt.xlabel('Age')
plt.show()

plt.scatter(range(len(meta_data['age'])),meta_data['age'], marker='.')
plt.grid()
plt.xlabel('Subject')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ### Set up a simple medical image viewer and import SimpleITK

# %%
import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt

from ipywidgets import interact, fixed
from IPython.display import display

from utils2.image_viewer import display_image

# %% [markdown]
# ### Imaging data
#
# Let's check out the imaging data that is available for each subject. This cell also shows how to retrieve data given a particular subject ID from the meta data.

# %%
import glob

# Subject with index 0
ID = meta_data['ID'][0]
age = meta_data['age'][0]

# Data folders
image_dir = data_dir + 'images/'
image_filenames = glob.glob(image_dir + '*.nii.gz')

mask_dir = data_dir + 'masks/'
mask_filenames = glob.glob(mask_dir + '*.nii.gz')

greymatter_dir = data_dir + 'greymatter/'
greymatter_filenames = glob.glob(greymatter_dir + '*.nii.gz')


image_filename = [f for f in image_filenames if ID in f][0]
img = sitk.ReadImage(image_filename)

mask_filename = [f for f in mask_filenames if ID in f][0]
msk = sitk.ReadImage(mask_filename)

greymatter_filename = [f for f in greymatter_filenames if ID in f][0]
gm = sitk.ReadImage(greymatter_filename)

print('Imaging data of subject ' + ID + ' with age ' + str(age))

print('\nMR Image (used in part A)')
display_image(img, window=400, level=200)

print('Brain mask (used in part A)')
display_image(msk)

print('Spatially normalised grey matter maps (used in part B)')
display_image(gm)
# Out:
# Imaging data of subject CC110033 with age 24
#
# MR Image (used in part A)
# Brain mask (used in part A)
# Spatially normalised grey matter maps (used in part B)

# %% [markdown]
# ## Part A: Volume-based regression using brain structure segmentation
#
# The first approach aims to regress the age of a subject using the volumes of brain tissues as features. The structures include grey matter (GM), white matter (WM), and cerebrospinal fluid (CSF). It is known that with increasing age the ventricles enlarge (filled with CSF), while it is assumed that grey and white matter volume may decrease over time. However, as overall brain volume varies across individuals, taking the absolute volumes of tissues might not be predictive. Instead, relative volumes need to be computed as the ratios between each tissue volume and overall brain volume. To this end, a four-class (GM, WM, CSF, and background) brain segmentation needs to be implemented and applied to the 600 brain scans. Brain masks are provided which have been generated with a state-of-the-art neuroimaging brain extraction tool.
#
# Different regression techniques should be explored, and it might be beneficial to investigate what the best set of features is for this task. Are all volume features equally useful, or is it even better to combine some of them and create new features. How does a simple linear regression perform compared to a model with higher order polynomials? Do you need regularisation? How about other regression methods such as regression trees or neural networks? The accuracy of different methods should be evaluated using two-fold cross-validation, and average age prediction accuracy should be compared and reported appropriately.
#
# *Note:* For part A, only the MR images and the brain masks should be used from the imaging data. The spatially normalised grey matter maps are used in part B only. If you struggle with task A-1, you can continue with A-2 using the provided reference segmentations in subfolder `segs_refs`.

# %% [markdown]
# ### TASK A-1: Brain tissue segmentation
#
# Implement a CNN model for brain tissue segmentation which can provide segmentations of GM, WM, and CSF. For this task (and only for this task), we provide a separate dataset of 52 subjects which are split into 47 images for training and 5 for validation. The template code below has the data handling and main training routines already implemented, so you can focus on implementing a suitable CNN model. A simple model is provided, but this won't perform very well.
#
# Once your model is trained and you are happy with the results on the validation data you should apply it to the 600 test images. We provide reference segmentations in a subfolder `segs_refs` for all subjects. Calculate Dice similarity coefficients per tissue when comparing your predicted segmentations for the 600 test images to the reference segmentations. Summarise the statistics of the 600 Dice scores for each tissue class in [box-and-whisker-plots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html).
#
# *Note:* Implementing a full-fledged machine learning pipeline with training and testing procedures in Jupyter notebooks is a bit cumbersome and a pain to debug. Also, running bigger training tasks can be unstable. The code below should work as is on your VM. However, if you want to get a bit more serious about implementing an advanced CNN approach for image segmentation, you may want to move code into separate Python scripts and run them from the terminal.

# %% [markdown]
# #### Imports

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from utils2.data_helper import ImageSegmentationDataset

# %% [markdown]
# #### Check that the GPU is up and running

# %%
cuda_dev = '0' #GPU device 0 (can be changed if multiple GPUs are available)

use_cuda = torch.cuda.is_available()
device = torch.device("cuda:" + cuda_dev if use_cuda else "cpu")

print('Device: ' + str(device))
if use_cuda:
    print('GPU: ' + str(torch.cuda.get_device_name(int(cuda_dev))))
# Out:
# Device: cuda:0
# GPU: Tesla K80

# %% [markdown]
# #### Config and hyper-parameters
#
# Here we set some default hyper-parameters and a starting configuration for the image resolution and others.
#
# **This needs to be revisited to optimise these values. In particular, you may want to run your final model on higher resolution images.**

# %%
rnd_seed = 42 #fixed random seed

img_size = [64, 64, 64]
img_spacing = [3, 3, 3]

# These parameters have been moved closer to the model training
# num_epochs = 60
# learning_rate = 0.0008
# batch_size = 10
# val_interval = 10

num_classes = 4

out_dir = './output'

# Create output directory
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %% [markdown]
# #### Loading and pre-processing of training and validation data
#
# We apply some standard pre-processing on the data such as intensity normalization (zero mean unit variance) and downsampling according to the configuration above.
#
# **We provide a 'debug' csv file pointing to just a few images for training. Replace this with the full training dataset when you train your full model.**

# %%
# USE THIS FOR TRAINING ON ALL 47 SUBJECTS
train_data = data_dir + 'train/csv/train.csv'

# USE THIS FOR DEBUGGING WITH JUST 2 SUBJECTS
# train_data = data_dir + 'train/csv/train_debug.csv'

val_data = data_dir + 'train/csv/val.csv'

print('LOADING TRAINING DATA...')
dataset_train = ImageSegmentationDataset(train_data, img_spacing, img_size)
dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

print('\nLOADING VALIDATION DATA...')
dataset_val = ImageSegmentationDataset(val_data, img_spacing, img_size)
dataloader_val = torch.utils.data.DataLoader(dataset_val, batch_size=1, shuffle=False)
# Out:
# LOADING TRAINING DATA...
# + reading image msub-CC110319_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110319.nii.gz
# + reading mask sub-CC110319_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120208_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120208.nii.gz
# + reading mask sub-CC120208_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120462_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120462.nii.gz
# + reading mask sub-CC120462_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121144_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121144.nii.gz
# + reading mask sub-CC121144_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC122405_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC122405.nii.gz
# + reading mask sub-CC122405_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210422_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210422.nii.gz
# + reading mask sub-CC210422_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220203_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220203.nii.gz
# + reading mask sub-CC220203_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220518_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220518.nii.gz
# + reading mask sub-CC220518_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221220_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221220.nii.gz
# + reading mask sub-CC221220_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221595_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221595.nii.gz
# + reading mask sub-CC221595_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222120_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222120.nii.gz
# + reading mask sub-CC222120_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222956_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222956.nii.gz
# + reading mask sub-CC222956_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310203_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310203.nii.gz
# + reading mask sub-CC310203_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310407_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310407.nii.gz
# + reading mask sub-CC310407_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320089_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320089.nii.gz
# + reading mask sub-CC320089_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320336_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320336.nii.gz
# + reading mask sub-CC320336_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320574_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320574.nii.gz
# + reading mask sub-CC320574_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321069_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321069.nii.gz
# + reading mask sub-CC321069_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321428_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321428.nii.gz
# + reading mask sub-CC321428_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321899_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321899.nii.gz
# + reading mask sub-CC321899_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410113_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410113.nii.gz
# + reading mask sub-CC410113_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410243_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410243.nii.gz
# + reading mask sub-CC410243_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410432_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410432.nii.gz
# + reading mask sub-CC410432_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420137_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420137.nii.gz
# + reading mask sub-CC420137_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420202_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420202.nii.gz
# + reading mask sub-CC420202_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420286_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420286.nii.gz
# + reading mask sub-CC420286_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420888_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420888.nii.gz
# + reading mask sub-CC420888_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC510226_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC510226.nii.gz
# + reading mask sub-CC510226_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC510329_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC510329.nii.gz
# + reading mask sub-CC510329_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC510474_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC510474.nii.gz
# + reading mask sub-CC510474_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC520002_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC520002.nii.gz
# + reading mask sub-CC520002_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC520134_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC520134.nii.gz
# + reading mask sub-CC520134_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC520253_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC520253.nii.gz
# + reading mask sub-CC520253_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC520503_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC520503.nii.gz
# + reading mask sub-CC520503_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC520775_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC520775.nii.gz
# + reading mask sub-CC520775_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC610288_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC610288.nii.gz
# + reading mask sub-CC610288_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC610575_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC610575.nii.gz
# + reading mask sub-CC610575_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620073_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620073.nii.gz
# + reading mask sub-CC620073_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620262_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620262.nii.gz
# + reading mask sub-CC620262_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620444_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620444.nii.gz
# + reading mask sub-CC620444_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620557_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620557.nii.gz
# + reading mask sub-CC620557_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620821_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620821.nii.gz
# + reading mask sub-CC620821_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621642_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621642.nii.gz
# + reading mask sub-CC621642_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710416_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710416.nii.gz
# + reading mask sub-CC710416_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720103_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720103.nii.gz
# + reading mask sub-CC720103_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720511_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720511.nii.gz
# + reading mask sub-CC720511_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721291_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721291.nii.gz
# + reading mask sub-CC721291_T1w_rigid_to_mni_brain_mask.nii.gz
#
# LOADING VALIDATION DATA...
# + reading image msub-CC220901_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220901.nii.gz
# + reading mask sub-CC220901_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320698_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320698.nii.gz
# + reading mask sub-CC320698_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420454_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420454.nii.gz
# + reading mask sub-CC420454_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC610058_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC610058.nii.gz
# + reading mask sub-CC610058_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710679_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710679.nii.gz
# + reading mask sub-CC710679_T1w_rigid_to_mni_brain_mask.nii.gz

# %% [markdown]
# #### Visualise training example
#
# Just to check how a training image looks like after pre-processing.

# %%
sample = dataset_train.get_sample(0)
img_name = dataset_train.get_img_name(0)
seg_name = dataset_train.get_seg_name(0)
print('Image: ' + img_name)
display_image(sample['img'], window=5, level=0)
print('Segmentation: ' + seg_name)
display_image(sitk.LabelToRGB(sample['seg']))
print('Mask')
display_image(sample['msk'])
# Out:
# Image: msub-CC110319_T1w_rigid_to_mni.nii.gz
# Segmentation: CC110319.nii.gz
# Mask

# %% [markdown]
# #### The Model
#
# This is the **key part of task A-1** where you have to design a suitable CNN model for brain segmentation. The simple model provided below works to some degree (it let's you run through the upcoming cells), but it will not perform very well. Use what you learned in the lectures to come up with a good architecture. Start with a simple, shallow model and only increase complexity (e.g., number of layers) if needed.

# %%
# Simple copy of LeNet Architecture, as studied in the tutorials,
# adapted for 3D convolutions

# Results on the test set (after training on full, batch_size=2, epochs=60)
# Jaccard Index - 0.7179323057859126
# Dice Similarity Coefficient - 0.8356534770415086
# Hausdorff Distance - 6.835040340530593
# Average Hausdorff Distance - 0.19918370770340751

# Training Epoch: 50 Loss: 0.783403
# Jaccard Index - 0.7036743389035195
# Dice Similarity Coefficient - 0.8258827020775221

class LeNet3D(nn.Module):
    def __init__(self, num_classes):
        super(LeNet3D, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv3d(1, 6, kernel_size=3, padding=1), 
            nn.ReLU(),
            nn.Conv3d(6, 16, kernel_size=3, padding=1), 
            nn.ReLU(),
            nn.Conv3d(16, 120, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv3d(120, 84, kernel_size=1),
            nn.ReLU(),
            nn.Conv3d(84, num_classes, kernel_size=1),
            nn.Softmax(dim = 1)          
        )
        
    def forward(self, x):
        return self.encoder(x)

# %%
# Simple copy of LeNet Architecture, as studied in the tutorials,
# adapted for 3D convolutions and using LeakyReLU as activations.

class LeNet3DLeaky(nn.Module):
    def __init__(self, num_classes):
        super(LeNet3DLeaky, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv3d(1, 6, kernel_size=3, padding=1), 
            nn.LeakyReLU(),
            nn.Conv3d(6, 16, kernel_size=3, padding=1), 
            nn.LeakyReLU(),
            nn.Conv3d(16, 120, kernel_size=3, padding=1),
            nn.LeakyReLU(),
            nn.Conv3d(120, 84, kernel_size=1),
            nn.LeakyReLU(),
            nn.Conv3d(84, num_classes, kernel_size=1),
            nn.Softmax(dim = 1)          
        )
        
    def forward(self, x):
        return self.encoder(x)

# %%
class LeNet3D_v3(nn.Module):
    def __init__(self, num_classes):
        super(LeNet3D_v3, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv3d(1, 6, kernel_size=3, padding=1), 
            nn.LeakyReLU(),
            nn.Conv3d(6, 16, kernel_size=3, padding=1), 
            nn.LeakyReLU(),
            nn.Conv3d(16, 120, kernel_size=3, padding=1),
            nn.LeakyReLU(),
            nn.Conv3d(120, 84, kernel_size=1),
            nn.LeakyReLU(),
            nn.Conv3d(84, 16, kernel_size=1),
            nn.LeakyReLU(),
            nn.Conv3d(16, num_classes, kernel_size=1),
            nn.Softmax(dim = 1)          
        )
        
    def forward(self, x):
        return self.encoder(x)

# %%
# Training 	 Epoch: 59 	 Loss: 0.782483
# Jaccard Index - 0.711565628959301
# Dice Similarity Coefficient - 0.8312905830514404

# Jaccard Index - 0.7148987542889228
# Dice Similarity Coefficient - 0.8336182412490798
# Hausdorff Distance - 7.336865015513813
# Average Hausdorff Distance - 0.2055263416428337

class LeNet3D_down_up(nn.Module):
    def __init__(self, num_classes):
        super(LeNet3D_down_up, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv3d(1, 6, kernel_size=3, padding=1), 
            nn.LeakyReLU(),
            nn.Conv3d(6, 16, kernel_size=3, padding=1), 
            nn.LeakyReLU(),
            nn.Conv3d(16, 120, kernel_size=3, padding=1),
            nn.LeakyReLU(),
            nn.Conv3d(120, 84, kernel_size=1),
            nn.LeakyReLU(),
            nn.Conv3d(84, 16, kernel_size=1),
            nn.LeakyReLU(),
            nn.Conv3d(16, num_classes, kernel_size=1),
            nn.Softmax(dim = 1)          
        )
        
    def forward(self, x):
        return self.encoder(x)

# %%
# Hyperparameters

num_epochs = 10
learning_rate = 0.0008
batch_size = 10
val_interval = 10

# %%
def train_model(model, optimizer, num_epochs=100, learning_rate=0.0006, batch_size=5, val_interval=10):
    loss_train_log = []
    loss_val_log = []
    epoch_val_log = []

    print('Start training...')
    for epoch in range(num_epochs):
        # Training
        for batch_idx, batch_samples in enumerate(dataloader_train):
            print('Training on batch ' + str(batch_idx) + "...")
            
            # Get image and reference segmentation
            img, seg = batch_samples['img'].to(device), batch_samples['seg'].to(device)
            
            # Optimizer clears gradiends
            optimizer.zero_grad()

            # Predict the classes for img, has shape
            # [batch_size, num_classes, img_size, img_size, img_size]
            # [2, 4, 64, 64, 64]
            prd = model(img)
            
            # Prepare data for cross_entropy   
            # [batch_size, num_classes, img_size ** 3]
            # [2, 4, 262144]
            prd_flat = prd.view(prd.size(0), prd.size(1), -1)
            seg_flat = seg.view(seg.size(0), seg.size(1), -1)
            
            loss = F.cross_entropy(prd_flat, seg_flat.squeeze(1))
            loss.backward()
            optimizer.step()

        loss_train_log.append(loss.item())

        print('Training \t Epoch: {} \t Loss: {:.6f}'.format(epoch, loss.item()))

        # Validation
        if epoch == 0 or epoch % val_interval == 0 or epoch == (num_epochs - 1):
            loss_val = 0
            sum_pts = 0
            idx_valid = 0
            
            jaccard_valid = 0
            dice_valid = 0
            
            with torch.no_grad():
                for data_sample in dataloader_val:
                    img, seg = data_sample['img'].to(device), data_sample['seg'].to(device)
                    
                    prd = model(img)
                    prd_flat = prd.view(prd.size(0), prd.size(1), -1)
                    seg_flat = seg.view(seg.size(0), seg.size(1), -1)
                    
                    loss_val += F.cross_entropy(prd_flat, seg_flat.squeeze(1), reduction='sum').item()
                    sum_pts += seg_flat.size(2)
                    
                    pred = torch.argmax(prd, dim=1)

                    sample = dataset_val.get_sample(idx_valid)
                    name = dataset_val.get_seg_name(idx_valid)

                    # Note: in the original implementation, type was np.uint8,
                    # different from what sample['seg'] provides (int64)
                    prediction = sitk.GetImageFromArray(pred.cpu().squeeze().numpy().astype(np.int64))
                    prediction.CopyInformation(sample['seg'])
                    sitk.WriteImage(prediction, os.path.join(pred_dir, name))

                    ref = sample['seg']        

                    overlap_measures_filter.Execute(ref, prediction)
                    jaccard_valid += overlap_measures_filter.GetJaccardCoefficient()
                    dice_valid += overlap_measures_filter.GetDiceCoefficient()

                    idx_valid += 1

                    
            jaccard_valid /= idx_valid
            dice_valid /= idx_valid

            print('Jaccard Index - ' + str(jaccard_valid))
            print('Dice Similarity Coefficient - ' + str(dice_valid))
            
            # Take highest probability per voxel
            prd = torch.argmax(prd, dim=1)
            
            # Convert prediction to SITK image
            # Function might be needed for Dice
            prediction = sitk.GetImageFromArray(prd.cpu().squeeze().numpy().astype(np.uint8))

            loss_val /= sum_pts

            loss_val_log.append(loss_val)
            epoch_val_log.append(epoch)

            print('--------------------------------------------------')
            print('+ Validate \t Epoch: {} \t Loss: {:.6f}'.format(epoch, loss_val))
            display_image(sitk.LabelToRGB(prediction))
            print('--------------------------------------------------')

    torch.save(model.state_dict(), os.path.join(model_dir, 'model.pt'))

    print('Finished training.')

    plt.plot(range(1, num_epochs + 1), loss_train_log, c='r', label='train')
    plt.plot(epoch_val_log, loss_val_log, c='b', label='val')
    plt.legend(loc='upper right')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()

# %% [markdown]
# #### TRAINING
#
# Below is an implementation of a full training procedure including a loop for intermediate evaluation of the model on the validation data. Feel free to modify this procedure. For example, in addition to the loss you may want to monitor precision, recall and Dice scores (or others).

# %%
model_dir = os.path.join(out_dir, 'model')
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

torch.manual_seed(rnd_seed) #fix random seed

model = LeNet3D(num_classes=num_classes).to(device)
model.train()
    
optimizer = torch.optim.Adam(model.parameters(), lr=0.0006)

train_model(model, optimizer, batch_size=10)
# Out:
# Start training...
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 0 	 Loss: 1.377362
# Jaccard Index - 0.04430231216058313
# Dice Similarity Coefficient - 0.0847834593085579
# --------------------------------------------------
# + Validate 	 Epoch: 0 	 Loss: 1.374347
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 1 	 Loss: 1.360977
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 2 	 Loss: 1.330668
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 3 	 Loss: 1.263592
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 4 	 Loss: 1.137680
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 5 	 Loss: 0.969720
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 6 	 Loss: 0.872152
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 7 	 Loss: 0.852248
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 8 	 Loss: 0.834818
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 9 	 Loss: 0.833925
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 10 	 Loss: 0.825004
# Jaccard Index - 0.48171054999700524
# Dice Similarity Coefficient - 0.6500563105178051
# --------------------------------------------------
# + Validate 	 Epoch: 10 	 Loss: 0.827756
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 11 	 Loss: 0.827164
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 12 	 Loss: 0.818100
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 13 	 Loss: 0.818584
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 14 	 Loss: 0.812862
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 15 	 Loss: 0.817405
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 16 	 Loss: 0.815291
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 17 	 Loss: 0.810351
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 18 	 Loss: 0.811524
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 19 	 Loss: 0.808714
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 20 	 Loss: 0.809265
# Jaccard Index - 0.5631108859060494
# Dice Similarity Coefficient - 0.7203255921429725
# --------------------------------------------------
# + Validate 	 Epoch: 20 	 Loss: 0.811386
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 21 	 Loss: 0.807675
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 22 	 Loss: 0.806968
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 23 	 Loss: 0.803883
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 24 	 Loss: 0.804766
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 25 	 Loss: 0.801375
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 26 	 Loss: 0.800223
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 27 	 Loss: 0.798351
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 28 	 Loss: 0.794775
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 29 	 Loss: 0.795551
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 30 	 Loss: 0.797149
# Jaccard Index - 0.6237297061384341
# Dice Similarity Coefficient - 0.7681230739734767
# --------------------------------------------------
# + Validate 	 Epoch: 30 	 Loss: 0.800283
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 31 	 Loss: 0.795521
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 32 	 Loss: 0.793912
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 33 	 Loss: 0.794831
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 34 	 Loss: 0.793475
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 35 	 Loss: 0.794166
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 36 	 Loss: 0.791130
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 37 	 Loss: 0.790978
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 38 	 Loss: 0.794337
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 39 	 Loss: 0.791903
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 40 	 Loss: 0.792140
# Jaccard Index - 0.6534552793779399
# Dice Similarity Coefficient - 0.790132329091495
# --------------------------------------------------
# + Validate 	 Epoch: 40 	 Loss: 0.794924
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 41 	 Loss: 0.790137
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 42 	 Loss: 0.788370
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 43 	 Loss: 0.790537
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 44 	 Loss: 0.791887
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 45 	 Loss: 0.788220
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 46 	 Loss: 0.786539
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 47 	 Loss: 0.789298
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 48 	 Loss: 0.786030
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 49 	 Loss: 0.786592
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 50 	 Loss: 0.786387
# Jaccard Index - 0.6793750895878704
# Dice Similarity Coefficient - 0.8088792795288494
# --------------------------------------------------
# + Validate 	 Epoch: 50 	 Loss: 0.790233
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 51 	 Loss: 0.785675
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 52 	 Loss: 0.783520
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 53 	 Loss: 0.785087
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 54 	 Loss: 0.784824
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 55 	 Loss: 0.786134
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 56 	 Loss: 0.785042
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 57 	 Loss: 0.784342
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 58 	 Loss: 0.786893
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 59 	 Loss: 0.783914
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 60 	 Loss: 0.784287
# Jaccard Index - 0.6946999773792558
# Dice Similarity Coefficient - 0.819632649207677
# --------------------------------------------------
# + Validate 	 Epoch: 60 	 Loss: 0.787289
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 61 	 Loss: 0.781867
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 62 	 Loss: 0.782783
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 63 	 Loss: 0.783301
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 64 	 Loss: 0.782345
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 65 	 Loss: 0.779464
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 66 	 Loss: 0.780718
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 67 	 Loss: 0.781103
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 68 	 Loss: 0.778695
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 69 	 Loss: 0.780731
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 70 	 Loss: 0.780911
# Jaccard Index - 0.7171625503244968
# Dice Similarity Coefficient - 0.8350854962607679
# --------------------------------------------------
# + Validate 	 Epoch: 70 	 Loss: 0.784068
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 71 	 Loss: 0.783935
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 72 	 Loss: 0.780470
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 73 	 Loss: 0.781267
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 74 	 Loss: 0.782625
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 75 	 Loss: 0.781219
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 76 	 Loss: 0.781677
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 77 	 Loss: 0.778765
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 78 	 Loss: 0.779658
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 79 	 Loss: 0.779106
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 80 	 Loss: 0.780246
# Jaccard Index - 0.7225182207960903
# Dice Similarity Coefficient - 0.838710695437664
# --------------------------------------------------
# + Validate 	 Epoch: 80 	 Loss: 0.782743
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 81 	 Loss: 0.778991
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 82 	 Loss: 0.780177
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 83 	 Loss: 0.781769
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 84 	 Loss: 0.777614
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 85 	 Loss: 0.780196
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 86 	 Loss: 0.778603
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 87 	 Loss: 0.778765
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 88 	 Loss: 0.779094
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 89 	 Loss: 0.777209
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 90 	 Loss: 0.778400
# Jaccard Index - 0.7274345638803572
# Dice Similarity Coefficient - 0.8420068654558838
# --------------------------------------------------
# + Validate 	 Epoch: 90 	 Loss: 0.781679
# --------------------------------------------------
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 91 	 Loss: 0.778307
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 92 	 Loss: 0.775877
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 93 	 Loss: 0.778570
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 94 	 Loss: 0.777895
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 95 	 Loss: 0.778777
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 96 	 Loss: 0.777294
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 97 	 Loss: 0.781168
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 98 	 Loss: 0.777773
# Training on batch 0...
# Training on batch 1...
# Training on batch 2...
# Training on batch 3...
# Training on batch 4...
# Training 	 Epoch: 99 	 Loss: 0.779091
# Jaccard Index - 0.7382273595012309
# Dice Similarity Coefficient - 0.8492223188597313
# --------------------------------------------------
# + Validate 	 Epoch: 99 	 Loss: 0.779960
# --------------------------------------------------
# Finished training.

# %% [markdown]
# #### Loading and pre-processing of testing data
#
# Now that we have trained a model, the next cells are about applying that model to our test dataset. Before testing on the full 600 subjects, you may want to initially just test on the 5 validation subjects.

# %%
# USE THIS FOR TESTING ON THE 600 SUBJECTS
test_data = data_dir + 'csv/test.csv'

# USE THIS FOR TESTING ON THE 5 VALIDATION SUBJECTS
# test_data = data_dir + 'train/csv/val.csv'

print('LOADING TESTING DATA...')
dataset_test = ImageSegmentationDataset(test_data, img_spacing, img_size)
dataloader_test = torch.utils.data.DataLoader(dataset_test, batch_size=1, shuffle=False)
# Out:
# LOADING TESTING DATA...
# + reading image msub-CC110033_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110033.nii.gz
# + reading mask sub-CC110033_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110037_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110037.nii.gz
# + reading mask sub-CC110037_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110045_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110045.nii.gz
# + reading mask sub-CC110045_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110056_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110056.nii.gz
# + reading mask sub-CC110056_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110062_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110062.nii.gz
# + reading mask sub-CC110062_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110069_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110069.nii.gz
# + reading mask sub-CC110069_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110087_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110087.nii.gz
# + reading mask sub-CC110087_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110098_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110098.nii.gz
# + reading mask sub-CC110098_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110101_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110101.nii.gz
# + reading mask sub-CC110101_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110126_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110126.nii.gz
# + reading mask sub-CC110126_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110174_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110174.nii.gz
# + reading mask sub-CC110174_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110182_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110182.nii.gz
# + reading mask sub-CC110182_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110187_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110187.nii.gz
# + reading mask sub-CC110187_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110411_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110411.nii.gz
# + reading mask sub-CC110411_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC110606_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC110606.nii.gz
# + reading mask sub-CC110606_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC112141_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC112141.nii.gz
# + reading mask sub-CC112141_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120008_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120008.nii.gz
# + reading mask sub-CC120008_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120049_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120049.nii.gz
# + reading mask sub-CC120049_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120061_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120061.nii.gz
# + reading mask sub-CC120061_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120065_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120065.nii.gz
# + reading mask sub-CC120065_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120120_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120120.nii.gz
# + reading mask sub-CC120120_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120123_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120123.nii.gz
# + reading mask sub-CC120123_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120166_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120166.nii.gz
# + reading mask sub-CC120166_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120182_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120182.nii.gz
# + reading mask sub-CC120182_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120218_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120218.nii.gz
# + reading mask sub-CC120218_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120234_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120234.nii.gz
# + reading mask sub-CC120234_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120264_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120264.nii.gz
# + reading mask sub-CC120264_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120276_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120276.nii.gz
# + reading mask sub-CC120276_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120286_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120286.nii.gz
# + reading mask sub-CC120286_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120309_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120309.nii.gz
# + reading mask sub-CC120309_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120313_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120313.nii.gz
# + reading mask sub-CC120313_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120319_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120319.nii.gz
# + reading mask sub-CC120319_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120347_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120347.nii.gz
# + reading mask sub-CC120347_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120376_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120376.nii.gz
# + reading mask sub-CC120376_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120409_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120409.nii.gz
# + reading mask sub-CC120409_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120469_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120469.nii.gz
# + reading mask sub-CC120469_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120470_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120470.nii.gz
# + reading mask sub-CC120470_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120550_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120550.nii.gz
# + reading mask sub-CC120550_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120640_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120640.nii.gz
# + reading mask sub-CC120640_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120727_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120727.nii.gz
# + reading mask sub-CC120727_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120764_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120764.nii.gz
# + reading mask sub-CC120764_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120795_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120795.nii.gz
# + reading mask sub-CC120795_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120816_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120816.nii.gz
# + reading mask sub-CC120816_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC120987_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC120987.nii.gz
# + reading mask sub-CC120987_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121106_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121106.nii.gz
# + reading mask sub-CC121106_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121111_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121111.nii.gz
# + reading mask sub-CC121111_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121158_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121158.nii.gz
# + reading mask sub-CC121158_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121194_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121194.nii.gz
# + reading mask sub-CC121194_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121200_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121200.nii.gz
# + reading mask sub-CC121200_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121317_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121317.nii.gz
# + reading mask sub-CC121317_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121397_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121397.nii.gz
# + reading mask sub-CC121397_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121411_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121411.nii.gz
# + reading mask sub-CC121411_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121428_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121428.nii.gz
# + reading mask sub-CC121428_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121479_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121479.nii.gz
# + reading mask sub-CC121479_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121685_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121685.nii.gz
# + reading mask sub-CC121685_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC121795_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC121795.nii.gz
# + reading mask sub-CC121795_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC122172_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC122172.nii.gz
# + reading mask sub-CC122172_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC122620_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC122620.nii.gz
# + reading mask sub-CC122620_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210023_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210023.nii.gz
# + reading mask sub-CC210023_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210051_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210051.nii.gz
# + reading mask sub-CC210051_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210088_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210088.nii.gz
# + reading mask sub-CC210088_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210124_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210124.nii.gz
# + reading mask sub-CC210124_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210148_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210148.nii.gz
# + reading mask sub-CC210148_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210172_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210172.nii.gz
# + reading mask sub-CC210172_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210182_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210182.nii.gz
# + reading mask sub-CC210182_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210250_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210250.nii.gz
# + reading mask sub-CC210250_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210304_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210304.nii.gz
# + reading mask sub-CC210304_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210314_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210314.nii.gz
# + reading mask sub-CC210314_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210519_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210519.nii.gz
# + reading mask sub-CC210519_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210526_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210526.nii.gz
# + reading mask sub-CC210526_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210617_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210617.nii.gz
# + reading mask sub-CC210617_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC210657_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC210657.nii.gz
# + reading mask sub-CC210657_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC212153_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC212153.nii.gz
# + reading mask sub-CC212153_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220098_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220098.nii.gz
# + reading mask sub-CC220098_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220107_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220107.nii.gz
# + reading mask sub-CC220107_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220115_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220115.nii.gz
# + reading mask sub-CC220115_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220132_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220132.nii.gz
# + reading mask sub-CC220132_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220151_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220151.nii.gz
# + reading mask sub-CC220151_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220198_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220198.nii.gz
# + reading mask sub-CC220198_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220223_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220223.nii.gz
# + reading mask sub-CC220223_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220232_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220232.nii.gz
# + reading mask sub-CC220232_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220234_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220234.nii.gz
# + reading mask sub-CC220234_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220284_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220284.nii.gz
# + reading mask sub-CC220284_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220323_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220323.nii.gz
# + reading mask sub-CC220323_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220335_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220335.nii.gz
# + reading mask sub-CC220335_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220352_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220352.nii.gz
# + reading mask sub-CC220352_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220372_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220372.nii.gz
# + reading mask sub-CC220372_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220394_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220394.nii.gz
# + reading mask sub-CC220394_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220419_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220419.nii.gz
# + reading mask sub-CC220419_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220506_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220506.nii.gz
# + reading mask sub-CC220506_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220519_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220519.nii.gz
# + reading mask sub-CC220519_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220526_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220526.nii.gz
# + reading mask sub-CC220526_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220535_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220535.nii.gz
# + reading mask sub-CC220535_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220567_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220567.nii.gz
# + reading mask sub-CC220567_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220610_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220610.nii.gz
# + reading mask sub-CC220610_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220635_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220635.nii.gz
# + reading mask sub-CC220635_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220697_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220697.nii.gz
# + reading mask sub-CC220697_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220713_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220713.nii.gz
# + reading mask sub-CC220713_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220806_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220806.nii.gz
# + reading mask sub-CC220806_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220828_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220828.nii.gz
# + reading mask sub-CC220828_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220843_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220843.nii.gz
# + reading mask sub-CC220843_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220920_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220920.nii.gz
# + reading mask sub-CC220920_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220974_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220974.nii.gz
# + reading mask sub-CC220974_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC220999_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC220999.nii.gz
# + reading mask sub-CC220999_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221002_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221002.nii.gz
# + reading mask sub-CC221002_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221031_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221031.nii.gz
# + reading mask sub-CC221031_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221033_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221033.nii.gz
# + reading mask sub-CC221033_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221038_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221038.nii.gz
# + reading mask sub-CC221038_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221040_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221040.nii.gz
# + reading mask sub-CC221040_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221054_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221054.nii.gz
# + reading mask sub-CC221054_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221107_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221107.nii.gz
# + reading mask sub-CC221107_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221209_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221209.nii.gz
# + reading mask sub-CC221209_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221244_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221244.nii.gz
# + reading mask sub-CC221244_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221324_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221324.nii.gz
# + reading mask sub-CC221324_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221336_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221336.nii.gz
# + reading mask sub-CC221336_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221352_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221352.nii.gz
# + reading mask sub-CC221352_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221373_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221373.nii.gz
# + reading mask sub-CC221373_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221487_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221487.nii.gz
# + reading mask sub-CC221487_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221511_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221511.nii.gz
# + reading mask sub-CC221511_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221527_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221527.nii.gz
# + reading mask sub-CC221527_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221565_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221565.nii.gz
# + reading mask sub-CC221565_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221580_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221580.nii.gz
# + reading mask sub-CC221580_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221585_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221585.nii.gz
# + reading mask sub-CC221585_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221648_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221648.nii.gz
# + reading mask sub-CC221648_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221733_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221733.nii.gz
# + reading mask sub-CC221733_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221740_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221740.nii.gz
# + reading mask sub-CC221740_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221755_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221755.nii.gz
# + reading mask sub-CC221755_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221775_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221775.nii.gz
# + reading mask sub-CC221775_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221828_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221828.nii.gz
# + reading mask sub-CC221828_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221886_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221886.nii.gz
# + reading mask sub-CC221886_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221935_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221935.nii.gz
# + reading mask sub-CC221935_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221954_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221954.nii.gz
# + reading mask sub-CC221954_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221977_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221977.nii.gz
# + reading mask sub-CC221977_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC221980_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC221980.nii.gz
# + reading mask sub-CC221980_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222125_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222125.nii.gz
# + reading mask sub-CC222125_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222185_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222185.nii.gz
# + reading mask sub-CC222185_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222258_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222258.nii.gz
# + reading mask sub-CC222258_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222264_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222264.nii.gz
# + reading mask sub-CC222264_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222304_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222304.nii.gz
# + reading mask sub-CC222304_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222326_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222326.nii.gz
# + reading mask sub-CC222326_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222367_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222367.nii.gz
# + reading mask sub-CC222367_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222496_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222496.nii.gz
# + reading mask sub-CC222496_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222555_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222555.nii.gz
# + reading mask sub-CC222555_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222652_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222652.nii.gz
# + reading mask sub-CC222652_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC222797_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC222797.nii.gz
# + reading mask sub-CC222797_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC223085_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC223085.nii.gz
# + reading mask sub-CC223085_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC223115_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC223115.nii.gz
# + reading mask sub-CC223115_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC223286_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC223286.nii.gz
# + reading mask sub-CC223286_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310008_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310008.nii.gz
# + reading mask sub-CC310008_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310051_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310051.nii.gz
# + reading mask sub-CC310051_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310052_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310052.nii.gz
# + reading mask sub-CC310052_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310086_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310086.nii.gz
# + reading mask sub-CC310086_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310129_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310129.nii.gz
# + reading mask sub-CC310129_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310135_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310135.nii.gz
# + reading mask sub-CC310135_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310142_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310142.nii.gz
# + reading mask sub-CC310142_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310160_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310160.nii.gz
# + reading mask sub-CC310160_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310214_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310214.nii.gz
# + reading mask sub-CC310214_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310224_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310224.nii.gz
# + reading mask sub-CC310224_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310252_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310252.nii.gz
# + reading mask sub-CC310252_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310256_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310256.nii.gz
# + reading mask sub-CC310256_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310331_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310331.nii.gz
# + reading mask sub-CC310331_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310361_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310361.nii.gz
# + reading mask sub-CC310361_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310385_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310385.nii.gz
# + reading mask sub-CC310385_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310391_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310391.nii.gz
# + reading mask sub-CC310391_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310397_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310397.nii.gz
# + reading mask sub-CC310397_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310400_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310400.nii.gz
# + reading mask sub-CC310400_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310402_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310402.nii.gz
# + reading mask sub-CC310402_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310410_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310410.nii.gz
# + reading mask sub-CC310410_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310414_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310414.nii.gz
# + reading mask sub-CC310414_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310450_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310450.nii.gz
# + reading mask sub-CC310450_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310463_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310463.nii.gz
# + reading mask sub-CC310463_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC310473_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC310473.nii.gz
# + reading mask sub-CC310473_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC312058_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC312058.nii.gz
# + reading mask sub-CC312058_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC312222_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC312222.nii.gz
# + reading mask sub-CC312222_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320002_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320002.nii.gz
# + reading mask sub-CC320002_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320022_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320022.nii.gz
# + reading mask sub-CC320022_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320059_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320059.nii.gz
# + reading mask sub-CC320059_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320088_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320088.nii.gz
# + reading mask sub-CC320088_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320107_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320107.nii.gz
# + reading mask sub-CC320107_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320109_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320109.nii.gz
# + reading mask sub-CC320109_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320160_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320160.nii.gz
# + reading mask sub-CC320160_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320202_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320202.nii.gz
# + reading mask sub-CC320202_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320206_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320206.nii.gz
# + reading mask sub-CC320206_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320218_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320218.nii.gz
# + reading mask sub-CC320218_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320267_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320267.nii.gz
# + reading mask sub-CC320267_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320269_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320269.nii.gz
# + reading mask sub-CC320269_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320297_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320297.nii.gz
# + reading mask sub-CC320297_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320321_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320321.nii.gz
# + reading mask sub-CC320321_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320325_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320325.nii.gz
# + reading mask sub-CC320325_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320342_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320342.nii.gz
# + reading mask sub-CC320342_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320359_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320359.nii.gz
# + reading mask sub-CC320359_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320379_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320379.nii.gz
# + reading mask sub-CC320379_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320417_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320417.nii.gz
# + reading mask sub-CC320417_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320429_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320429.nii.gz
# + reading mask sub-CC320429_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320448_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320448.nii.gz
# + reading mask sub-CC320448_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320461_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320461.nii.gz
# + reading mask sub-CC320461_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320478_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320478.nii.gz
# + reading mask sub-CC320478_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320500_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320500.nii.gz
# + reading mask sub-CC320500_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320553_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320553.nii.gz
# + reading mask sub-CC320553_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320568_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320568.nii.gz
# + reading mask sub-CC320568_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320575_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320575.nii.gz
# + reading mask sub-CC320575_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320576_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320576.nii.gz
# + reading mask sub-CC320576_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320608_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320608.nii.gz
# + reading mask sub-CC320608_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320616_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320616.nii.gz
# + reading mask sub-CC320616_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320621_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320621.nii.gz
# + reading mask sub-CC320621_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320636_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320636.nii.gz
# + reading mask sub-CC320636_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320651_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320651.nii.gz
# + reading mask sub-CC320651_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320661_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320661.nii.gz
# + reading mask sub-CC320661_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320680_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320680.nii.gz
# + reading mask sub-CC320680_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320686_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320686.nii.gz
# + reading mask sub-CC320686_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320687_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320687.nii.gz
# + reading mask sub-CC320687_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320759_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320759.nii.gz
# + reading mask sub-CC320759_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320776_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320776.nii.gz
# + reading mask sub-CC320776_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320814_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320814.nii.gz
# + reading mask sub-CC320814_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320850_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320850.nii.gz
# + reading mask sub-CC320850_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320870_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320870.nii.gz
# + reading mask sub-CC320870_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320888_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320888.nii.gz
# + reading mask sub-CC320888_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320893_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320893.nii.gz
# + reading mask sub-CC320893_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC320904_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC320904.nii.gz
# + reading mask sub-CC320904_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321000_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321000.nii.gz
# + reading mask sub-CC321000_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321025_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321025.nii.gz
# + reading mask sub-CC321025_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321053_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321053.nii.gz
# + reading mask sub-CC321053_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321073_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321073.nii.gz
# + reading mask sub-CC321073_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321087_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321087.nii.gz
# + reading mask sub-CC321087_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321107_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321107.nii.gz
# + reading mask sub-CC321107_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321137_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321137.nii.gz
# + reading mask sub-CC321137_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321154_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321154.nii.gz
# + reading mask sub-CC321154_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321174_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321174.nii.gz
# + reading mask sub-CC321174_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321203_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321203.nii.gz
# + reading mask sub-CC321203_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321281_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321281.nii.gz
# + reading mask sub-CC321281_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321291_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321291.nii.gz
# + reading mask sub-CC321291_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321331_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321331.nii.gz
# + reading mask sub-CC321331_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321368_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321368.nii.gz
# + reading mask sub-CC321368_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321431_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321431.nii.gz
# + reading mask sub-CC321431_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321464_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321464.nii.gz
# + reading mask sub-CC321464_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321504_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321504.nii.gz
# + reading mask sub-CC321504_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321506_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321506.nii.gz
# + reading mask sub-CC321506_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321529_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321529.nii.gz
# + reading mask sub-CC321529_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321544_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321544.nii.gz
# + reading mask sub-CC321544_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321557_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321557.nii.gz
# + reading mask sub-CC321557_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321585_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321585.nii.gz
# + reading mask sub-CC321585_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321594_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321594.nii.gz
# + reading mask sub-CC321594_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321595_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321595.nii.gz
# + reading mask sub-CC321595_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321880_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321880.nii.gz
# + reading mask sub-CC321880_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC321976_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC321976.nii.gz
# + reading mask sub-CC321976_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC322186_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC322186.nii.gz
# + reading mask sub-CC322186_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410015_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410015.nii.gz
# + reading mask sub-CC410015_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410032_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410032.nii.gz
# + reading mask sub-CC410032_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410040_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410040.nii.gz
# + reading mask sub-CC410040_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410084_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410084.nii.gz
# + reading mask sub-CC410084_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410086_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410086.nii.gz
# + reading mask sub-CC410086_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410091_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410091.nii.gz
# + reading mask sub-CC410091_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410094_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410094.nii.gz
# + reading mask sub-CC410094_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410097_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410097.nii.gz
# + reading mask sub-CC410097_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410101_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410101.nii.gz
# + reading mask sub-CC410101_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410119_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410119.nii.gz
# + reading mask sub-CC410119_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410121_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410121.nii.gz
# + reading mask sub-CC410121_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410129_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410129.nii.gz
# + reading mask sub-CC410129_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410169_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410169.nii.gz
# + reading mask sub-CC410169_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410173_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410173.nii.gz
# + reading mask sub-CC410173_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410177_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410177.nii.gz
# + reading mask sub-CC410177_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410179_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410179.nii.gz
# + reading mask sub-CC410179_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410182_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410182.nii.gz
# + reading mask sub-CC410182_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410220_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410220.nii.gz
# + reading mask sub-CC410220_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410222_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410222.nii.gz
# + reading mask sub-CC410222_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410226_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410226.nii.gz
# + reading mask sub-CC410226_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410248_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410248.nii.gz
# + reading mask sub-CC410248_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410251_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410251.nii.gz
# + reading mask sub-CC410251_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410284_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410284.nii.gz
# + reading mask sub-CC410284_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410287_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410287.nii.gz
# + reading mask sub-CC410287_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410289_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410289.nii.gz
# + reading mask sub-CC410289_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410297_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410297.nii.gz
# + reading mask sub-CC410297_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410323_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410323.nii.gz
# + reading mask sub-CC410323_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410325_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410325.nii.gz
# + reading mask sub-CC410325_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410354_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410354.nii.gz
# + reading mask sub-CC410354_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410387_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410387.nii.gz
# + reading mask sub-CC410387_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC410390_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC410390.nii.gz
# + reading mask sub-CC410390_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC412004_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC412004.nii.gz
# + reading mask sub-CC412004_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC412021_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC412021.nii.gz
# + reading mask sub-CC412021_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420004_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420004.nii.gz
# + reading mask sub-CC420004_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420060_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420060.nii.gz
# + reading mask sub-CC420060_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420061_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420061.nii.gz
# + reading mask sub-CC420061_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420071_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420071.nii.gz
# + reading mask sub-CC420071_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420075_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420075.nii.gz
# + reading mask sub-CC420075_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420089_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420089.nii.gz
# + reading mask sub-CC420089_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420091_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420091.nii.gz
# + reading mask sub-CC420091_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420094_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420094.nii.gz
# + reading mask sub-CC420094_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420100_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420100.nii.gz
# + reading mask sub-CC420100_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420143_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420143.nii.gz
# + reading mask sub-CC420143_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420148_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420148.nii.gz
# + reading mask sub-CC420148_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420149_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420149.nii.gz
# + reading mask sub-CC420149_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420157_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420157.nii.gz
# + reading mask sub-CC420157_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420162_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420162.nii.gz
# + reading mask sub-CC420162_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420167_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420167.nii.gz
# + reading mask sub-CC420167_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420173_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420173.nii.gz
# + reading mask sub-CC420173_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420180_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420180.nii.gz
# + reading mask sub-CC420180_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420182_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420182.nii.gz
# + reading mask sub-CC420182_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420197_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420197.nii.gz
# + reading mask sub-CC420197_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420198_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420198.nii.gz
# + reading mask sub-CC420198_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420204_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420204.nii.gz
# + reading mask sub-CC420204_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420217_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420217.nii.gz
# + reading mask sub-CC420217_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420222_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420222.nii.gz
# + reading mask sub-CC420222_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420226_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420226.nii.gz
# + reading mask sub-CC420226_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420229_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420229.nii.gz
# + reading mask sub-CC420229_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420231_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420231.nii.gz
# + reading mask sub-CC420231_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420236_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420236.nii.gz
# + reading mask sub-CC420236_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420241_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC420241.nii.gz
# + reading mask sub-CC420241_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC420259_T1w_rigid_to_mni.nii.gz
# ...
# + reading mask sub-CC620560_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620567_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620567.nii.gz
# + reading mask sub-CC620567_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620572_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620572.nii.gz
# + reading mask sub-CC620572_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620592_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620592.nii.gz
# + reading mask sub-CC620592_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620610_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620610.nii.gz
# + reading mask sub-CC620610_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620619_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620619.nii.gz
# + reading mask sub-CC620619_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620659_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620659.nii.gz
# + reading mask sub-CC620659_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620685_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620685.nii.gz
# + reading mask sub-CC620685_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620720_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620720.nii.gz
# + reading mask sub-CC620720_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620785_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620785.nii.gz
# + reading mask sub-CC620785_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620793_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620793.nii.gz
# + reading mask sub-CC620793_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620885_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620885.nii.gz
# + reading mask sub-CC620885_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620919_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620919.nii.gz
# + reading mask sub-CC620919_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC620935_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC620935.nii.gz
# + reading mask sub-CC620935_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621011_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621011.nii.gz
# + reading mask sub-CC621011_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621080_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621080.nii.gz
# + reading mask sub-CC621080_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621118_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621118.nii.gz
# + reading mask sub-CC621118_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621128_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621128.nii.gz
# + reading mask sub-CC621128_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621184_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621184.nii.gz
# + reading mask sub-CC621184_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621199_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621199.nii.gz
# + reading mask sub-CC621199_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621248_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621248.nii.gz
# + reading mask sub-CC621248_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC621284_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC621284.nii.gz
# + reading mask sub-CC621284_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710037_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710037.nii.gz
# + reading mask sub-CC710037_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710088_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710088.nii.gz
# + reading mask sub-CC710088_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710099_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710099.nii.gz
# + reading mask sub-CC710099_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710131_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710131.nii.gz
# + reading mask sub-CC710131_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710154_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710154.nii.gz
# + reading mask sub-CC710154_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710176_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710176.nii.gz
# + reading mask sub-CC710176_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710214_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710214.nii.gz
# + reading mask sub-CC710214_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710313_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710313.nii.gz
# + reading mask sub-CC710313_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710342_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710342.nii.gz
# + reading mask sub-CC710342_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710350_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710350.nii.gz
# + reading mask sub-CC710350_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710382_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710382.nii.gz
# + reading mask sub-CC710382_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710429_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710429.nii.gz
# + reading mask sub-CC710429_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710446_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710446.nii.gz
# + reading mask sub-CC710446_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710462_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710462.nii.gz
# + reading mask sub-CC710462_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710486_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710486.nii.gz
# + reading mask sub-CC710486_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710494_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710494.nii.gz
# + reading mask sub-CC710494_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710518_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710518.nii.gz
# + reading mask sub-CC710518_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710548_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710548.nii.gz
# + reading mask sub-CC710548_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710551_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710551.nii.gz
# + reading mask sub-CC710551_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710566_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710566.nii.gz
# + reading mask sub-CC710566_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710591_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710591.nii.gz
# + reading mask sub-CC710591_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710664_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710664.nii.gz
# + reading mask sub-CC710664_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710858_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710858.nii.gz
# + reading mask sub-CC710858_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC710982_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC710982.nii.gz
# + reading mask sub-CC710982_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC711027_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC711027.nii.gz
# + reading mask sub-CC711027_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC711035_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC711035.nii.gz
# + reading mask sub-CC711035_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC711128_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC711128.nii.gz
# + reading mask sub-CC711128_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC711158_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC711158.nii.gz
# + reading mask sub-CC711158_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC711244_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC711244.nii.gz
# + reading mask sub-CC711244_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC711245_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC711245.nii.gz
# + reading mask sub-CC711245_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC712027_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC712027.nii.gz
# + reading mask sub-CC712027_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720023_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720023.nii.gz
# + reading mask sub-CC720023_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720071_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720071.nii.gz
# + reading mask sub-CC720071_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720119_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720119.nii.gz
# + reading mask sub-CC720119_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720180_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720180.nii.gz
# + reading mask sub-CC720180_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720188_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720188.nii.gz
# + reading mask sub-CC720188_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720238_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720238.nii.gz
# + reading mask sub-CC720238_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720290_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720290.nii.gz
# + reading mask sub-CC720290_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720304_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720304.nii.gz
# + reading mask sub-CC720304_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720329_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720329.nii.gz
# + reading mask sub-CC720329_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720358_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720358.nii.gz
# + reading mask sub-CC720358_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720400_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720400.nii.gz
# + reading mask sub-CC720400_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720407_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720407.nii.gz
# + reading mask sub-CC720407_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720497_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720497.nii.gz
# + reading mask sub-CC720497_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720516_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720516.nii.gz
# + reading mask sub-CC720516_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720622_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720622.nii.gz
# + reading mask sub-CC720622_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720646_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720646.nii.gz
# + reading mask sub-CC720646_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720670_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720670.nii.gz
# + reading mask sub-CC720670_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720685_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720685.nii.gz
# + reading mask sub-CC720685_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720941_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720941.nii.gz
# + reading mask sub-CC720941_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC720986_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC720986.nii.gz
# + reading mask sub-CC720986_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721052_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721052.nii.gz
# + reading mask sub-CC721052_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721107_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721107.nii.gz
# + reading mask sub-CC721107_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721114_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721114.nii.gz
# + reading mask sub-CC721114_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721224_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721224.nii.gz
# + reading mask sub-CC721224_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721292_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721292.nii.gz
# + reading mask sub-CC721292_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721374_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721374.nii.gz
# + reading mask sub-CC721374_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721377_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721377.nii.gz
# + reading mask sub-CC721377_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721392_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721392.nii.gz
# + reading mask sub-CC721392_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721418_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721418.nii.gz
# + reading mask sub-CC721418_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721434_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721434.nii.gz
# + reading mask sub-CC721434_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721504_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721504.nii.gz
# + reading mask sub-CC721504_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721519_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721519.nii.gz
# + reading mask sub-CC721519_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721532_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721532.nii.gz
# + reading mask sub-CC721532_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721585_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721585.nii.gz
# + reading mask sub-CC721585_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721618_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721618.nii.gz
# + reading mask sub-CC721618_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721648_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721648.nii.gz
# + reading mask sub-CC721648_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721704_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721704.nii.gz
# + reading mask sub-CC721704_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721707_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721707.nii.gz
# + reading mask sub-CC721707_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721729_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721729.nii.gz
# + reading mask sub-CC721729_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721888_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721888.nii.gz
# + reading mask sub-CC721888_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721891_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721891.nii.gz
# + reading mask sub-CC721891_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC721894_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC721894.nii.gz
# + reading mask sub-CC721894_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC722216_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC722216.nii.gz
# + reading mask sub-CC722216_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC722421_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC722421.nii.gz
# + reading mask sub-CC722421_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC722536_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC722536.nii.gz
# + reading mask sub-CC722536_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC722542_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC722542.nii.gz
# + reading mask sub-CC722542_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC722651_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC722651.nii.gz
# + reading mask sub-CC722651_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC722891_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC722891.nii.gz
# + reading mask sub-CC722891_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC723197_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC723197.nii.gz
# + reading mask sub-CC723197_T1w_rigid_to_mni_brain_mask.nii.gz
# + reading image msub-CC723395_T1w_rigid_to_mni.nii.gz
# + reading segmentation CC723395.nii.gz
# + reading mask sub-CC723395_T1w_rigid_to_mni_brain_mask.nii.gz

# %% [markdown]
# #### Visualise testing example
#
# Just to check how a testing image looks like after pre-processing.

# %%
sample = dataset_test.get_sample(0)
img_name = dataset_test.get_img_name(0)
seg_name = dataset_test.get_seg_name(0)
print('Image: ' + img_name)
display_image(sample['img'], window=5, level=0)
print('Segmentation: ' + seg_name)
display_image(sitk.LabelToRGB(sample['seg']))
print('Mask')
display_image(sample['msk'])
# Out:
# Image: msub-CC110033_T1w_rigid_to_mni.nii.gz
# Segmentation: CC110033.nii.gz
# Mask

# %% [markdown]
# #### TESTING
#
# Below is an implementation of a full testing procedure that saves the segmentations in an output folder. Feel free to modify this procedure.
#
# **You will need to add the calculations of Dice scores (and possibly others) to evaluate the segmentation performance.**

# %%
pred_dir = os.path.join(out_dir, 'pred')
if not os.path.exists(pred_dir):
    os.makedirs(pred_dir)

model = LeNet3D(num_classes=num_classes).to(device)  
# model = SimpleNet3D(num_classes=num_classes)
model.load_state_dict(torch.load(os.path.join(model_dir, 'model.pt')))
model.to(device)
model.eval()

# Overlap and Hausdorff filters, as presented in the Summary
overlap_measures_filter = sitk.LabelOverlapMeasuresImageFilter()
hausdorff_distance_filter = sitk.HausdorffDistanceImageFilter()
    
print('START TESTING...')

loss_test = 0
sum_pts = 0
idx_test = 0
jaccard_test = 0
dice_test = 0
hausdorff_test = 0
avg_hausdorff_test = 0

with torch.no_grad():
    for data_sample in dataloader_test:
        img, seg = data_sample['img'].to(device), data_sample['seg'].to(device)
        prd = model(img)
        prd_flat = prd.view(prd.size(0), prd.size(1), -1)
        seg_flat = seg.view(seg.size(0), seg.size(1), -1)
        loss_test += F.cross_entropy(prd_flat, seg_flat.squeeze(1), reduction='sum').item()
        sum_pts += seg_flat.size(2)        
        
        prd = torch.argmax(prd, dim=1)

        sample = dataset_test.get_sample(idx_test)
        name = dataset_test.get_seg_name(idx_test)
        
        # Note: in the original implementation, type was np.uint8,
        # different from what sample['seg'] provides (int64)
        prediction = sitk.GetImageFromArray(prd.cpu().squeeze().numpy().astype(np.int64))
        prediction.CopyInformation(sample['seg'])
        sitk.WriteImage(prediction, os.path.join(pred_dir, name))
        
        ref = sample['seg']        
        
        overlap_measures_filter.Execute(ref, prediction)
        jaccard_test += overlap_measures_filter.GetJaccardCoefficient()
        dice_test += overlap_measures_filter.GetDiceCoefficient()

        ref_contour = sitk.LabelContour(ref)
        prediction_contour = sitk.LabelContour(prediction)
        
        hausdorff_distance_filter.Execute(ref_contour, prediction_contour)
        hausdorff_test += hausdorff_distance_filter.GetHausdorffDistance()
        avg_hausdorff_test += hausdorff_distance_filter.GetAverageHausdorffDistance()
        
        idx_test += 1
        
loss_test /= sum_pts
jaccard_test /= idx_test
dice_test /= idx_test
hausdorff_test /= idx_test
avg_hausdorff_test /= idx_test

print('+ TESTING \tLoss: {:.6f}'.format(loss_test))

# Show last testing sample as an example
print('\n\nReference segmentation')
display_image(sitk.LabelToRGB(sample['seg']))
print('Predicted segmentation')
display_image(sitk.LabelToRGB(prediction))

print('Jaccard Index - ' + str(jaccard_test))
print('Dice Similarity Coefficient - ' + str(dice_test))
print('Hausdorff Distance - ' + str(hausdorff_test))
print('Average Hausdorff Distance - ' + str(avg_hausdorff_test))


print('\nFinished TESTING.')
# Out:
# START TESTING...
# + TESTING 	Loss: 0.776483
#
#
# Reference segmentation
# Predicted segmentation
# Jaccard Index - 0.7408662378592895
# Dice Similarity Coefficient - 0.8510361366956087
# Hausdorff Distance - 6.608331206840275
# Average Hausdorff Distance - 0.16836878135581698
#
# Finished TESTING.

# %% [markdown]
# ### TASK A-2: Feature calculation
#
# Start by calculating the three absolute tissue volumes for each subject. Plot the volumes against the subjects' ages. Taking the absolute volumes of tissues as features, however, might not be predictive. Instead, relative volumes need to be computed as the ratios between each tissue volume and overall brain volume. But you might also want to explore using different combinations or even polynomial features.
#
# Implement a function that constructs a big matrix $X$ with a row for each subject and features across the columns. Start with just calculating three simple features of relative tissue volumes for GM, WM and CSF, and compare these to the absolute volumes plotted above.
#
# *Note:* If you are struggling with the previous task on image segmentation, or if you prefer to work on this and the following tasks first, you can continue here using the provided reference segmentations which can be found in a subfolder `segs_refs`.

# %%
## CALCULATE ABSOLUTE TISSUE VOLUMES
import glob
import os

# USE THIS TO RUN THE CALCULATIONS ON YOUR SEGMENTATONS
# seg_dir = './output/pred/'

# USE THIS TO RUN THE CALCULATIONS ON OUR REFERENCE SEGMENTATIONS
seg_dir = data_dir + './segs_refs/'

vols = np.zeros((3, meta_data['ID'].count()))

for i in range(meta_data['ID'].count()):
    segmentation_data = sitk.ReadImage(seg_dir + str(meta_data['ID'][i]) + '.nii.gz')
    segmentation_array = sitk.GetArrayFromImage(segmentation_data)
    segmentation_array = segmentation_array.flatten()
    
    vols[0, i] = segmentation_array[segmentation_array == 1].shape[0]
    vols[1, i] = segmentation_array[segmentation_array == 2].shape[0]
    vols[2, i] = segmentation_array[segmentation_array == 3].shape[0]
    
print(vols)

# %% [markdown]
# Plot features versus age.

# %%
print("Gray matter")
plt.scatter(meta_data['age'], vols[0, :], marker='.')
plt.xlabel('Gray matter volume')
plt.ylabel('Age')
plt.show()

print("White matter")
plt.scatter(meta_data['age'], vols[1, :], marker='.')
plt.xlabel('White matter volume')
plt.ylabel('Age')
plt.show()

print("CSF")
plt.scatter(meta_data['age'], vols[2, :], marker='.')
plt.xlabel('CSF volume')
plt.ylabel('Age')
plt.show()
# Out:
# Gray matter
# White matter
# CSF

# %%
## CALCULATE RELATIVE TISSUE VOLUMES

vols_normalised = np.zeros((3, meta_data['ID'].count()))
vols_normalised = vols / vols.sum(axis=0)

# %%
X = vols_normalised.T
y = meta_data['age'].values.reshape(-1,1)

print(X.shape)
print(y.shape)
# Out:
# (600, 3)
# (600, 1)

# %%
print("Gray matter")
plt.scatter(y, X[:, 0], marker='.')
plt.xlabel('Gray matter volume')
plt.ylabel('Age')
plt.show()

print("White matter")
plt.scatter(y, X[:, 1], marker='.')
plt.xlabel('White matter volume')
plt.ylabel('Age')
plt.show()

print("CSF")
plt.scatter(y, X[:, 2], marker='.')
plt.xlabel('CSF volume')
plt.ylabel('Age')
plt.show()
# Out:
# Gray matter
# White matter
# CSF

# %% [markdown]
# ### TASK A-3: Age regression and cross-validation
#
# Experiment with different regression methods from the [scikit-learn toolkit](http://scikit-learn.org/stable/supervised_learning.html#supervised-learning). Remember to construct the output vectur $y$ containing the age for each of the subjects.
#
# Evaluate the methods using two-fold [cross-validation](http://scikit-learn.org/stable/modules/cross_validation.html#cross-validation) where the dataset of 600 subjects is split into two equally sized sets $(X_1,y_1)$ and $(X_2,y_2)$ which are used for training and testing in an alternating way (so each set is used as $(X_{\text{train}},y_{\text{train}})$ and $(X_{\text{test}},y_{\text{test}})$ exactly once).
#
# Try using at least three different regression methods, and generate a plot allows easy comparison of the performance of the three methods. Useful [error metrics](https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics) to report include mean absolute error and r2 score. You might also want to plot the real vs predicted ages.
#
# *Note:* These [scikit-learn examples](https://scikit-learn.org/stable/auto_examples/) might serve as an inspiration.
#
# *Hint:* Be careful how you split the dataset into two folds. Take into account the data characteristics shown at the top of the notebook.

# %%
from sklearn import linear_model
from sklearn.model_selection import KFold
from sklearn.metrics import explained_variance_score, mean_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.ensemble import RandomForestClassifier
from sklearn.base import clone

def plot_reg(x, y_pred, y_true):
    plt.scatter(y_true, range(y_true.shape[0]), label="True")
    plt.scatter(y_pred, range(y_pred.shape[0]), label="Predicted")
    plt.legend()
    plt.show()

models = [
    linear_model.LinearRegression(),
    linear_model.Ridge(alpha=.5),
    linear_model.Lasso(alpha=0.1),
    linear_model.BayesianRidge(),
    RandomForestClassifier(n_estimators=100, max_depth=120, random_state=42)
]

def cross_validation(models, X, y):
    kf = KFold(n_splits=2, shuffle=True)
    
    for model in models:
        print("Model: " + str(model))

        evs = 0
        mae = 0
        mse = 0
        msle = 0
        best_mae = 0
        best = []
        splits = kf.split(X)
        
        for idx, (train_index, test_index) in enumerate(splits):
            cur_model = clone(model)
            cur_model.fit(X[train_index], y[train_index])
            y_pred = cur_model.predict(X[test_index])
            y_true = y[test_index]

            # output score
            evs_fold = explained_variance_score(y_true, y_pred)
            mae_fold = mean_absolute_error(y_true, y_pred)
            mse_fold = mean_squared_error(y_true, y_pred)
            msle_fold = 0#mean_squared_log_error(y_true, y_pred)  

            evs += evs_fold
            mae += mae_fold
            mse += mse_fold
            msle += msle_fold

            """
            print("Fold %d:"
                  "\n\texplained_variance_score: %.3f"
                  "\n\tmean_absolute_error: %.3f"
                  "\n\tmean_squared_error: %.3f"
                  "\n\tmean_squared_log_error: %.3f" % (idx, evs_fold, mae_fold, mse_fold, msle_fold))
            """
            if mae_fold > best_mae:
                best_mae = mae_fold
                best = [cur_model, X[test_index], y_pred, y_true]
        
        evs /= 2
        mae /= 2
        mse /= 2
        msle /= 2
        
        print("\nBest model:", end="")
        plot_reg(best[1], best[2], best[3])
        print("Average scores:"
          "\n\texplained_variance_score: %.3f"
          "\n\tmean_absolute_error: %.3f"
          "\n\tmean_squared_error: %.3f"
          "\n\tmean_squared_log_error: %.3f" % (evs, mae, mse, msle))
        print("\n")
        
cross_validation(models, X, y)
# Out:
# Model: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# Best model:
# Average scores:
# 	explained_variance_score: -1.131
# 	mean_absolute_error: 22.359
# 	mean_squared_error: 741.670
# 	mean_squared_log_error: 0.000
#
#
# Model: Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
#
# Best model:
# Average scores:
# 	explained_variance_score: -1.121
# 	mean_absolute_error: 21.823
# 	mean_squared_error: 736.515
# 	mean_squared_log_error: 0.000
#
#
# Model: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
#
# Best model:
# Average scores:
# 	explained_variance_score: -0.624
# 	mean_absolute_error: 19.572
# 	mean_squared_error: 566.277
# 	mean_squared_log_error: 0.000
#
#
# Model: BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# /data/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /data/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best model:
# Average scores:
# 	explained_variance_score: 0.000
# 	mean_absolute_error: 16.195
# 	mean_squared_error: 351.858
# 	mean_squared_log_error: 0.000
#
#
# Model: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=120, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# /data/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /data/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Best model:
# Average scores:
# 	explained_variance_score: -1.035
# 	mean_absolute_error: 22.190
# 	mean_squared_error: 717.603
# 	mean_squared_log_error: 0.000

# %% [markdown]
# ## Part B: Image-based regression using grey matter maps
#
# The second approach will make use of grey matter maps that have been already extracted from the MRI scans and aligned to a common reference space to obtain spatially normalised maps. For this, we have used an advanced, state-of-the-art neuroimaging toolkit, called SPM12. The reference space corresponds to the commonly used MNI atlas as seen in the lecture on image segmentation.
#
# Because these grey matter maps are spatially normalised (ie., registered), voxel locations across images from different subjects roughly correspond to the same anatomical locations. This means that each voxel location in the grey matter maps can be treated as an individual feature. Because those maps are quite large at their full resolution there would be a very large number of features to deal with (more than 850,000). A dimensionality reduction using PCA may need to be performed before training a suitable regressor on the low-dimensional feature representation obtained with PCA. It might also be beneficial to apply some pre-processing (downsampling, smoothing, etc.) before running PCA, which should be explored. The implemented pipeline should be evaluated using two-fold cross-validation using the same data splits as in part A, so the two different approaches can be directly compared in terms average age prediction accuracy.
#
# *Note:* For part B, only the spatially normalised grey matter maps should be used.

# %% [markdown]
# ### TASK B-1: Pre-processing
#
# Before running PCA to reduce the dimensionality of the feature space for grey matter maps, it might be beneficial to run some pre-processing on the maps. In voxel-based analysis where each voxel location is a feature, it is common to apply some smoothing beforehand. This is to reduce noise and to compensate for errors of the spatial normalisation that had been applied to the maps.
#
# Because the maps are quite large, it might also be worthwile to explore whether downsampling could be performed even before PCA. This would further reduce the dimensionality, and might be even needed in the case where PCA on the orignial resolution runs into memory issues. You may want to consider other ways of pre-processing and you can find insipiration in the notebook on medical image computing `MLI-MIC-Summary.ipynb`.
#
# Implement a function that performs suitable pre-processing on each grey matter map.
#
# *Hint:* You may want to save the pre-processed maps using `sitk.WriteImage` to avoid recomputation each time you run the notebook.

# %%
output_dir = "./save/"

def downsample_naive(img, factor=2):
    return img[::factor, ::factor, ::factor]

def downsample(img, factor=2):
    smoothed = sitk.DiscreteGaussian(img, (.5 * factor) ** 2)   
    return smoothed[::factor, ::factor, ::factor]

down_factor = 4

display_image(gm)
down_gm = downsample(gm, down_factor)
display_image(down_gm)

print(sitk.GetArrayFromImage(gm).shape)
print(sitk.GetArrayFromImage(down_gm).shape)

gms = list(map(lambda f: sitk.ReadImage(f), greymatter_filenames))
img_data = list(map(lambda img: downsample(img, down_factor), gms))

print("Start save")

for idx, img in enumerate(img_data):
    filename = output_dir + str(meta_data['ID'][idx]) + ".nii.gz"
    sitk.WriteImage(img, filename)
    
print("Done save")

print("Without down-sampling", np.array(list(map(lambda img: sitk.GetArrayFromImage(img), gms))).reshape(len(gms), -1).shape)
print("With down-sampling", np.array(list(map(lambda img: sitk.GetArrayFromImage(img), img_data))).reshape(len(img_data), -1).shape)
# Out:
# (90, 108, 90)
# (22, 27, 22)
# Start save
# Done save
# Without down-sampling (600, 874800)
# With down-sampling (600, 13068)

# %%
down_greymatter_filenames = glob.glob(output_dir + '*.nii.gz')
img_data = list(map(lambda f: sitk.ReadImage(f), down_greymatter_filenames))
img_data = np.array(list(map(lambda img: sitk.GetArrayFromImage(img), img_data)))

X = img_data #PRE-PROCESSED IMAGE DATA
y = meta_data['age'].values.reshape(-1, 1)

# print(img_size)
print(X.shape)
print(y.shape)
# Out:
# (600, 22, 27, 22)
# (600, 1)

# %% [markdown]
# ### TASK B-2: Dimensionality reduction
#
# Implement dimensionality reduction for grey matter maps using [scitkit-learn's PCA](http://scikit-learn.org/stable/modules/decomposition.html#pca). PCA has an option to set the percentage of variance to be preserved (by setting the parameter `n_components` to a value between 0 and 1). The number of principal modes, that is the new dimensionality of the data, is then automatically determined. Try initially to preserve 95% of the variance (`n_components=0.95`).
#
# *Note:* When dimensionality reduction is used as pre-processing step for supervised learning, as in this case, it is important that PCA is fitted to the training data only, but then applied to both the training and testing data. So make sure your implementation consists of two separate steps, 1) fitting the PCA model to $X_{\text{train}}$ (using the `fit` function), and 2) applying dimensionality reduction to $X_{\text{train}}$ and $X_{\text{test}}$ using the `transform` function.

# %%
import sklearn.decomposition as decomp

X = X.reshape(X.shape[0], -1)

print("Before reduction: ", X.shape)
plt.hist(X[0])
plt.show()

# samples = X.shape[0]

# Create PCA instance
pca = decomp.PCA(n_components=0.95)

# Fit the data
X = pca.fit_transform(X)

# Get the mean from PCA
# mu_X = pca.mean_

# Get principal modes (a.k.a. components) from PCA
# U = pca.components_.T

# Get the eigenvalues from PCA's singular values
# D = pca.singular_values_ ** 2 / (samples - 1)

# print("Mu: ", mu_X.shape)
# print("U: ", U.shape)
# print("D: ", D.shape)
print("After PCA: ", X.shape)
plt.hist(X[0])
plt.show()
# Out:
# Before reduction:  (600, 13068)
# After PCA:  (600, 463)

# %% [markdown]
# ### TASK B-3: Age regression and cross-validation
#
# Experiment with different regression methods from the [scikit-learn toolkit](http://scikit-learn.org/stable/supervised_learning.html#supervised-learning). Evaluate the methods using two-fold [cross-validation](http://scikit-learn.org/stable/modules/cross_validation.html#cross-validation) in the same way as for your approach in Part A so results can be directly compared. Generate the similar plots.
#
# Try using at least three different regression methods.
#
# *Hint:* Remember, when you use cross-validation where you swap training and testing sets in each fold, you need to fit PCA to the training set of each fold.

# %%
models = [
    linear_model.LinearRegression(),
    linear_model.Ridge(alpha=.5),
    linear_model.Lasso(alpha=0.1),
    linear_model.BayesianRidge(),
    RandomForestClassifier(n_estimators=100, max_depth=120, random_state=42)
]

cross_validation(models, X, y)
# Out:
# Model: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
#
# Best model:
# Average scores:
# 	explained_variance_score: -1.363
# 	mean_absolute_error: 23.229
# 	mean_squared_error: 821.507
# 	mean_squared_log_error: 0.000
#
#
# Model: Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)
#
# Best model:
# Average scores:
# 	explained_variance_score: -1.038
# 	mean_absolute_error: 21.623
# 	mean_squared_error: 723.837
# 	mean_squared_log_error: 0.000
#
#
# Model: Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)
#
# Best model:
# Average scores:
# 	explained_variance_score: -0.613
# 	mean_absolute_error: 19.607
# 	mean_squared_error: 570.813
# 	mean_squared_log_error: 0.000
#
#
# Model: BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=False, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)
# /data/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /data/anaconda/envs/py35/lib/python3.5/site-packages/sklearn/utils/validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best model:
# Average scores:
# 	explained_variance_score: -0.000
# 	mean_absolute_error: 16.148
# 	mean_squared_error: 349.349
# 	mean_squared_log_error: 0.000
#
#
# Model: RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=120, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)
# /data/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /data/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:37: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Best model:
# Average scores:
# 	explained_variance_score: -0.985
# 	mean_absolute_error: 21.570
# 	mean_squared_error: 694.397
# 	mean_squared_log_error: 0.000
